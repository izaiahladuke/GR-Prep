# %% [markdown]
# ## Lesson 5 Solution

# %% [markdown]
# 1)	Create an array containing 4 string elements: your first name, your last name, your birth state and your favorite color.

# %%
import numpy as np
from datascience import *

# %%
my_odds=np.arange(1,4256,4)
my_odds
# Out:
# array([   1,    5,    9, ..., 4245, 4249, 4253])

# %%
np.cumprod(my_odds,dtype=object)
# Out:
# array([1, 5, 45, ...,
#        ...,
#        ...,
#        ...],
#       dtype=object)

# %%
my_array=make_array("Ken","Horton","TX","Red")
print(my_array)
# Out:
# ['Ken' 'Horton' 'TX' 'Red']

# %% [markdown]
# a.	Use a numpy function to make all elements uppercase.

# %%
print(np.char.upper(my_array))
# Out:
# ['KEN' 'HORTON' 'TX' 'RED']

# %% [markdown]
# b.	Use a numpy function to count the number of times the letter “a” appears in each element of your array.

# %%
print(np.char.count(my_array,"a"))
# Out:
# [0 0 0 0]

# %% [markdown]
# c.	Optional: Use a numpy function to find the length of each element in the array. You may need to Google this.

# %%
mylen=np.vectorize(len)
print(mylen(my_array))
# Out:
# [3 6 2 3]

# %% [markdown]
# 2)	Create an array containing EVERY OTHER odd number starting with 1 and ending with (and including) 45.

# %%
my_range=np.arange(1,42,4)
print(my_range)
my_range = my_range.astype(float)
print(my_range)
# Out:
# [ 1  5  9 13 17 21 25 29 33 37 41]
# [ 1.  5.  9. 13. 17. 21. 25. 29. 33. 37. 41.]

# %% [markdown]
# a.	Use numpy to find the sum and the product of the elements of this array.

# %%
print(np.sum(my_range))
print(np.prod(my_range))
# Out:
# 231.0
# 7579867420125.0

# %% [markdown]
# b.	Use numpy to take the natural log of each element.

# %%
print(np.log(my_range))
# Out:
# [0.         1.60943791 2.19722458 2.56494936 2.83321334 3.04452244
#  3.21887582 3.36729583 3.49650756 3.61091791 3.71357207 3.80666249]

# %% [markdown]
# c.	Optional: The numpy function np.diff finds the difference between adjacent elements of an array. Find the SUM of adjacent elements of this array.

# %%
first=my_range[0:len(my_range)-1]
second=my_range[1:len(my_range)]
print(first+second)
# Out:
# [ 6 14 22 30 38 46 54 62 70 78 86]
